# %%
# %load_ext autoreload
# %autoreload 1
    
# %aimport neurons

# %aimport simple_fhn

import numpy as np
from neurons import *

# %%
t = np.linspace(0, 200, num=1500)
x0 = [0.5,-0.7]

FHN_neuron = FHN_Neuron(x0=x0, I_ext=3)
FHN_neuron.plot(FHN_neuron.solve(0, t),t)
FHN_neuron.plot(FHN_neuron.solve(0.5, t),t)
FHN_neuron.plot(FHN_neuron.solve(2, t),t)
# FHN_neuron.plot(1, t)

FHN_neuron.solve_ss(t)
# Out:
# Neuron __init__() called
# FHN Neuron __init__() called
# ('Roots: ', array([-1.19940804, -0.62426004]))

# %% [raw]
# print(FHN_neuron.y)

# %%
t = np.linspace(0, 200, num=2000)
x0 = [0.5,-0.7,-0.5]

R_neuron = Rinzel_Neuron(x0=x0, I_ext=3)

# r = R_neuron.solve(I, t, z)
R_neuron.plot(R_neuron.solve(1, t, 0),t)
R_neuron.plot(R_neuron.solve(0.5, t, 1),t)
R_neuron.plot(R_neuron.solve(0.5, t, 1),t)

R_neuron.solve_ss(t)
# Out:
# Neuron __init__() called
# FHN Neuron __init__() called
# Rinzel Neuron __init__() called
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-18164d7f05a2> in <module>
#       9 R_neuron.plot(R_neuron.solve(0.5, t, 1),t)
#      10
# ---> 11 R_neuron.solve_ss(t)
#
# ~/Development/Neuroscience/SysMIC/_Mini Project/neurons.py in solve_ss(self, t, I)
#      92
#      93     def solve_ss(self, t, I=0):
# ---> 94         eq = fsolve(self.dx_dt, self.x0, args=(t,I))
#      95         return "Roots: ", eq
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/optimize/minpack.py in fsolve(func, x0, args, fprime, full_output, col_deriv, xtol, maxfev, band, epsfcn, factor, diag)
#     158                'diag': diag}
#     159
# --> 160     res = _root_hybr(func, x0, args, jac=fprime, **options)
#     161     if full_output:
#     162         x = res['x']
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/optimize/minpack.py in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     224     if not isinstance(args, tuple):
#     225         args = (args,)
# --> 226     shape, dtype = _check_func('fsolve', 'func', func, x0, args, n, (n,))
#     227     if epsfcn is None:
#     228         epsfcn = finfo(dtype).eps
#
# ~/Library/Python/3.7/lib/python/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# TypeError: dx_dt() missing 1 required positional argument: 'z'
