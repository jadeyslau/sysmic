# %%
# %load_ext autoreload
# %autoreload 1
    
# %aimport neurons
# %aimport simple_fhn

import numpy as np
from neurons import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
t = np.linspace(0, 200, num=1500)
x0 = [0.5,-0.7]

FHN_neuron = FHN_Neuron(x0=x0, I_ext=3)
FHN_neuron.plot(FHN_neuron.solve(0, t),t)
FHN_neuron.plot(FHN_neuron.solve(0.5, t),t)
FHN_neuron.plot(FHN_neuron.solve(2, t),t)
# FHN_neuron.plot(1, t)

FHN_neuron.solve_ss(0,t)
# Out:
# Neuron __init__() called 0
# FHN Neuron __init__() called 3
# ('Roots: ', array([-1.19940804, -0.62426004]))

# %% [raw]
# print(FHN_neuron.y)

# %%
t = np.linspace(0, 200, num=1500)
x0 = [0.5,-0.7,0]

R_neuron = Rinzel_Neuron(x0=x0, I_ext=3)
# R_neuron.plot(Rinzel_Neuron.solve(0, 0, t))

Rinzel_Neuron.solve(0, t, 0)
# Out:
# Neuron __init__() called
# FHN Neuron __init__() called
# Rinzel Neuron __init__() called
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-1aec27f61392> in <module>
#       5 # R_neuron.plot(Rinzel_Neuron.solve(0, 0, t))
#       6
# ----> 7 Rinzel_Neuron.solve(0, 0, t)
#
# TypeError: solve() missing 1 required positional argument: 'z'
