# %%
# %load_ext autoreload
# %autoreload 1
    
# %aimport neurons
# %aimport simple_fhn

import numpy as np
import neurons as n
# import brainy_things_neuron as b
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
time_span = np.linspace(0, 200, num=1500)
x0 = [0.5,-0.7]

FHN_neuron = n.FHN_Neuron(x0=x0)
FHN_neuron.plot(0, time_span)
FHN_neuron.plot(0.5, time_span)
FHN_neuron.plot(2, time_span)
# FHN_neuron.plot(x0, 2, time_span)
# Out:
# [0.5, -0.7]
# (1500, 2)
# (1500, 2)
# (1500, 2)

# %% [raw]
# neuron = n

# %%
FHN_neuron.self_identifies()
# Out:
# "I'm a FitzHugh Nagamo neuron!"

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

def dx_dt(x, t):
    I   = 0.5
    a   = 0.7
    b   = 0.8
    tau = 12.5

    dvdt = x[0] - (x[0]**3/3) - x[1] + I
    dwdt = (x[0] + a - b*x[1]) / tau
    return [dvdt,dwdt]

# initial condition
x0 = [0.5,-0.7]
I = 0.5
# time points
t = np.linspace(0, 200, num=1500)

# solve ODE
y = odeint(dx_dt,x0,t)

# plot results
plt.plot(t,y)
plt.xlabel('time')
plt.ylabel('y(t)')
plt.show()
