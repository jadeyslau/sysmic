# %%
# %load_ext autoreload
# %autoreload 1
    
# %aimport neurons

import numpy as np
import neurons as n
# import brainy_things_neuron as b
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
neuron = n.Neuron()
x = np.linspace(0, 200, 300)
neuron.plot(np.sin(x))
# Out:
# plot

# %%
neuron.self_identifies()
# Out:
# "I'm a neuron!"
